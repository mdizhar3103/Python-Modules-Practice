# %% [markdown]
# ## Matplotlib
# - Matplotlib is python 2D plotting library which produces
# - publication quality figures in a variety of hardcopy formats and
# - interactive environments across platform.
#
# - Easy to create Plots
# - Embeddable GUI for application development
#
# - Pylab - make matplotlib work like MATLAB
# ```
#             Heirarchy
#
#             Figure
#                |
#               Axes
#                |
#               / \
#              /   \
#            Axis Axis
#             |
#            / \
#         Minor Major
#         Ticks Ticks
#
#
#     Figure is a top-level container
#     PyPlot API's operate at higher levels
#     Matplotlib API's at lower levels
#
#     Note: A figure can have more than one axes.
# ```

# %%
# Non-interactive mode

import matplotlib

print(matplotlib.__version__)
# Out:
# 3.4.3

# %%
matplotlib.is_interactive()
# Out:
# False

# %%
matplotlib.interactive(False)

# %%
# Another way of turn off interactive mode
import matplotlib.pyplot as plt

plt.ioff()
matplotlib.is_interactive()
# Out:
# False

# %%
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16])

# %%
# in non-interactice mode we have to call explicitly show

plt.show()

# %%
matplotlib.interactive(True)

# another way using plt.ion()

# %%
# plot will be shown wihout calling show()
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16])

# %%
# Working with interactive Backend -render to hardcopy or device

# list all available backends
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
import matplotlib

matplotlib.is_interactive()
# if false set to true
# matplotlib.interactive(True)
# Out:
# True

# %%
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
# matplotlib.get_backend()

# # setting backend
# matplotlib.use('nbagg')
# matplotlib.get_backend()

# %%
import matplotlib.pyplot as plt

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16])

# %%
plt.title("Interactive Plot")
# Out:
# Text(0.5, 1.0, 'Interactive Plot')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16])

# %%
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16],
        color = "red")

# %%
plt.plot([2, 4, 6, 8],
        [4, 8, 12, 16])

plt.xlabel('x', fontsize=15, color="green")
plt.ylabel('2*x', fontsize=15, color="green")
# Out:
# Text(0, 0.5, '2*x')

# %%
# Note: if only one list is passed it assumes it as Y-coordinates and its indexes as X-coordinate
plt.plot([4, 8, 12, 16])

# %%
x = np.linspace(start = 0, stop = 10, num = 50)

# %%
plt.plot(x, np.sin(x))
plt.xlabel('x', fontsize=15, color="green")
plt.ylabel('sin(x)', fontsize=15, color="green")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.tick_params(axis="y", 
               color="red",
               labelcolor="blue",
               labelsize="xx-large")

# %%
plt.tick_params(axis="x", 
               bottom=False,
               labelbottom=False)

# %%
plt.plot(x, np.sin(x))
plt.xlabel('x', fontsize=15, color="green")
plt.ylabel('sin(x)', fontsize=15, color="green")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()

# %%
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()
plt.title("Playing with Plots")
# Out:
# Text(0.5, 1.0, 'Playing with Plots')

# %%
# to get the only limit portion graph
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()
plt.title("Playing with Plots")
plt.xlim(1, 5)
# Out:
# (1.0, 5.0)

# %%
# to get the only x,y limit portion graph
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()
plt.title("Playing with Plots")
plt.xlim(1, 5)
plt.ylim(-1, 0.5)
# Out:
# (-1.0, 0.5)

# %%
# generating mirror image of previous graph by switching xlim parameters
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()
plt.title("Playing with Plots")
plt.xlim(5, 1)
plt.ylim(-1, 0.5)
# Out:
# (-1.0, 0.5)

# %%
# to get the only x,y limit portion graph
plt.plot(x, np.sin(x), label="sine curve")
plt.legend()
plt.title("Playing with Plots")
plt.xlim(5, 1)
plt.ylim(0.5, -1)
# Out:
# (0.5, -1.0)

# %%
# Working with Lines and Markers
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
x = np.linspace(start = 0, stop = 10, num = 50)
plt.plot(x, np.sin(x))
plt.show()

# %%
x = np.linspace(start = 0, stop = 10, num = 50)
plt.plot(x, np.sin(x), label="sine curve")
plt.plot(x, np.cos(x), label="cosine curve")

plt.legend()
plt.title("Playing with plots")

plt.show()

# %%
# customizing colors of graph
x = np.linspace(start = 0, stop = 10, num = 50)
plt.plot(x, np.sin(x), label="sine curve", color="green")
plt.plot(x, np.cos(x), label="cosine curve", color="m")

plt.legend()
plt.title("Playing with plots")

plt.show()

# %%
random_array = np.random.randn(20)

# %%
plt.plot(random_array, color="green")
plt.show()

# %%
# changing line style
plt.plot(random_array, 
         color="green",
         linestyle=':')
plt.show()

# %%
# changing line style
plt.plot(random_array, 
         color="green",
         linestyle='--')
plt.show()

# %% [markdown]
# - dotted line ':'
# - dashed line '--'

# %%
# changing line thickness
plt.plot(random_array, 
         color="green",
         linestyle=':', 
        linewidth=3)
plt.show()

# %%
# using marker for data points
plt.plot(random_array, 
         color="green",
         marker='d')
plt.show()

# %%
# using marker for data points
plt.plot(random_array, color="green", marker='d', markersize=10)
plt.show()

# %%
# using linstyle option
plt.plot(random_array, color="green", marker='d', markersize=10, linestyle='None')
plt.show()

# %%
# using scatter plots (x, Y) options
plt.scatter(range(0,20),random_array, color="green", marker='d')
plt.show()

# %%
# Figure and Axes
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
plt.show()

# Note: add_axes parameter denotes
# 0 - extreme left position 
# 2nd 0 - represents the bottom location of the axes in figure. 0 is the bottom of the figure 1 is the top of figure
# 3rd argument represents the width of the axes in terms of fraction of the figure width
# 4th argument represent the height of the axes in terms of fraction of the figure height

# %%
# Adding multiple axes on same figure

fig = plt.figure()
ax1 = fig.add_axes([0, 0.6, 1, 0.6])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])
plt.show()

# %%
x = np.linspace(start = 0, stop = 10, num = 50)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0.6, 1, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0.6, 1, 0.4])
ax2 = fig.add_axes([0, 0, 0.8, 0.4])

ax1.plot(x, np.sin(x))
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=15, color='r')

ax2.plot(x, np.cos(x))
ax2.set_xlabel('x', fontsize=15, color='r')
ax2.set_ylabel('cos(x)', fontsize=15, color='r')

plt.show()

# %%
# nesting the axes
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.5, 0.4, 0.4])
plt.show()

# %%
# explicitly defining figure size in inches
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.5, 0.4, 0.4])
plt.show()

# %%
# using grid number and subplot
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221) # 2x2 grid at position 1
plt.show()

# %%
type(ax1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
isinstance(ax1, matplotlib.axes._axes.Axes)
# subplot is derived class of Axes
# Out:
# True

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

plt.show()

# %%
# Figure and Axes
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
x = np.linspace(start = 0, stop = 10, num = 50)

# %%
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(224)
ax3.plot(x, np.cos(x))

plt.show()

# %%
# adding subplot out of position throws error
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(225)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-a65ec2383748> in <module>
#       1 # adding subplot out of position throws error
#       2 fig = plt.figure(figsize=(8,8))
# ----> 3 ax1 = fig.add_subplot(225)
#       4 ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
#       5 plt.show()
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     782             projection_class, pkw = self._process_projection_requirements(
#     783                 *args, **kwargs)
# --> 784             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     785             key = (projection_class, pkw)
#     786         return self._add_axes_internal(ax, key)
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
# ...

# %%
# another way of specifying subplot grid of specific size
"""Note: 
1st option is MxN grid size
2nd option indicate the row and column of subplot
"""
ax1 = plt.subplot2grid((2, 3), (0, 0))
ax1.plot(x, np.sin(x))
ax1.set_label('sine curve')

ax2 = plt.subplot2grid((2, 3), (0, 1))
ax2.plot(x, np.cos(x))
ax2.set_label('cosine curve')

ax3 = plt.subplot2grid((2, 3), (0, 2), rowspan=2)
ax3.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax3.set_label('straight line')

ax4 = plt.subplot2grid((2, 3), (1, 0), colspan=2)
ax4.plot(x, np.exp2(x))
ax4.set_label('exponential curve')

# %%
# Watermarks - Image and Text watermarks

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax.text(1, 4, 'Do not Distribute', fontsize=30, color='red',ha='left', va='bottom', alpha=0.5)
# Out:
# Text(1, 4, 'Do not Distribute')

# %%
x = np.linspace(start=0, stop=10, num=50)

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax1.set_label('Straight Line')
ax1.text(1, 4, 'Do not Distribute', fontsize=20, color='red', ha='left',va='bottom',alpha=0.5)
# Out:
# Text(1, 4, 'Do not Distribute')

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax1.set_label('Straight Line')
ax1.text(1, 4, 'Do not Distribute', fontsize=20, color='red', ha='left',va='bottom',alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

# %%
# adding text watermark to figure
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax1.set_label('Straight Line')
ax1.text(1, 4, 'Do not Distribute', fontsize=20, color='red', ha='left',va='bottom',alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

fig.text(0.1, 0.5, 'My Graphs', fontsize=40, color='grey', ha='left', va='bottom', alpha=0.3)
# Out:
# Text(0.1, 0.5, 'My Graphs')

# %%
# setting image as watermark
import matplotlib.image as image
import matplotlib.cbook as cbook

# %%
datafile = cbook.get_sample_data("C:\\Users\\500063372\\PYTHON_REPO\\autos\\Pics for assignment\\logo.png", asfileobj=False)

# %%
im = image.imread(datafile)

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4], [2, 4, 6, 8])
ax1.set_label('Straight Line')
ax1.text(1, 4, 'Do not Distribute', fontsize=20, color='red', ha='left',va='bottom',alpha=0.5)

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

fig.figimage(im, 100, 150, zorder=3, alpha=0.3)

# %%
# Drawing Shapes using Patch Module
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
fig, ax = plt.subplots()
ax.add_patch(
    patches.Rectangle(
        (0.1, 0.1), # left and bottom distance position from figure
        0.5, # fractional width of rectangle
        0.5, # fractional height of rectangle
        fill=False))
plt.show()

# %%
# Note: as rectangle appear smaller even the both size are in term of 0-1 
# this is because matplotlib uses aspect ration to maintain that

fig, ax = plt.subplots()
ax.set_aspect(aspect="equal")
ax.add_patch(
    patches.Rectangle(
        (0.1, 0.1), 
        0.5,
        0.5,
        fill=False))
plt.show()

# %%
# adding color to patch
fig, ax = plt.subplots()
ax.set_aspect(aspect="equal")
ax.add_patch(
    patches.Rectangle(
        (0.1, 0.1), 
        0.5,
        0.5,
        facecolor="yellow",
        edgecolor="green"))
plt.show()

# %%
# adding design to patches
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.3, 0.6, hatch='.'),
         patches.Rectangle((0.5, 0.1), 0.3, 0.6, hatch='\\', fill=False),
         ]:
    ax.add_patch(p)
    
plt.show()

# %%
# adding opacity to patches
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.2, 0.6, alpha=None),
          patches.Rectangle((0.4, 0.1), 0.2, 0.6, alpha=1.0),
          patches.Rectangle((0.7, 0.1), 0.2, 0.6, alpha=0.6),
          patches.Rectangle((1.0, 0.1), 0.2, 0.6, alpha=0.1)
         ]:
    ax.add_patch(p)
    
plt.show()
# note: the 4th rectangle is on extreme right of figure so it doesn't fit into figure and doesn't display

# %%
# to fix the above issue we need to fix the xlimit
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.2, 0.6, alpha=None),
          patches.Rectangle((0.4, 0.1), 0.2, 0.6, alpha=1.0),
          patches.Rectangle((0.7, 0.1), 0.2, 0.6, alpha=0.6),
          patches.Rectangle((1.0, 0.1), 0.2, 0.6, alpha=0.1)
         ]:
    ax.add_patch(p)
ax.set_xlim(0, 1.5)
plt.show()

# %%
# filling colors in patches
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.2, 0.6, facecolor=None),
          patches.Rectangle((0.4, 0.1), 0.2, 0.6, facecolor='none'),
          patches.Rectangle((0.7, 0.1), 0.2, 0.6, facecolor='red'),
          patches.Rectangle((1.0, 0.1), 0.2, 0.6, facecolor='#00ffff')
         ]:
    ax.add_patch(p)
ax.set_xlim(0, 1.5)
plt.show()

# %%
# specifying edge color and fill value
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.2, 0.6, fill=False,edgecolor=None),
          patches.Rectangle((0.4, 0.1), 0.2, 0.6, fill=False,edgecolor='none'),
          patches.Rectangle((0.7, 0.1), 0.2, 0.6, fill=False,edgecolor='red'),
          patches.Rectangle((1.0, 0.1), 0.2, 0.6, fill=False,edgecolor='#00ffff')
         ]:
    ax.add_patch(p)
ax.set_xlim(0, 1.5)
plt.show()

# %%
# formatting the line borders of patches
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Rectangle((0.1, 0.1), 0.2, 0.6, fill=False,linestyle='solid'),
          patches.Rectangle((0.4, 0.1), 0.2, 0.6, fill=False,linestyle='dashed'),
          patches.Rectangle((0.7, 0.1), 0.2, 0.6, fill=False,linestyle='dashdot'),
          patches.Rectangle((1.0, 0.1), 0.2, 0.6, fill=False,linestyle='dotted')
         ]:
    ax.add_patch(p)
ax.set_xlim(0, 1.5)
plt.show()

# %%
# other patch objects
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
for p in [patches.Circle((0.1, 0.4), 0.1, hatch='/'),
          patches.Circle((0.5, 0.4), 0.1, hatch='*',facecolor='red'),
          patches.Circle((0.9, 0.4), 0.1, hatch='\\',facecolor='green'),
          patches.Circle((0.5, 0.7), 0.1, hatch='//',fill=False)
         ]:
    ax.add_patch(p)
plt.show()

# %%
# drawing anykind of polygon (ex: 5 sided polygon)
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
polygon = patches.Polygon([[0.1, 0.1],
                         [0.2, 0.8],
                         [0.5, 0.7],
                         [0.8, 0.1],
                         [0.4, 0.3]],
                        fill = False)
ax.add_patch(polygon)
plt.show()

# %%
# by default polygon closes the vertices if you dont want use the option below
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
polygon = patches.Polygon([[0.1, 0.1],
                         [0.2, 0.8],
                         [0.5, 0.7],
                         [0.8, 0.1],
                         [0.4, 0.3]],
                          closed=False,
                        fill = False)
ax.add_patch(polygon)
plt.show()

# %%
# Creating Arrow patch
fx, ax = plt.subplots()
ax.set_aspect(aspect="equal")
polygon = patches.Arrow(0.1, 0.2, 0.7, 0.7)
ax.add_patch(polygon)
plt.show()

"1st arg: X, 2nd arg: Y, 3rd-4th: head of arrow coordinate"
# Out:
# '1st arg: X, 2nd arg: Y, 3rd-4th: head of arrow coordinate'

# %%
# Bezier Curve
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
fig,ax = plt.subplots()
p = patches.PathPatch(Path([(0.1, 0.1), (0.8, 0.8), (0.8, 0.1), (0.4, 0.2)],
                          [Path.MOVETO, Path.LINETO, Path.LINETO, Path.LINETO]),
                     fill=None)
ax.add_patch(p)
plt.show()

# %%
# closing the Beizer curve
fig,ax = plt.subplots()
p = patches.PathPatch(Path([(0.1, 0.1), (0.8, 0.8), (0.8, 0.1), (0.4, 0.2)],
                          [Path.MOVETO, Path.LINETO, Path.LINETO, Path.CLOSEPOLY]),
                     fill=None)
ax.add_patch(p)
plt.show()

# %%
# Plotting Quadratic Curve
fig,ax = plt.subplots()
p = patches.PathPatch(Path([(0.1, 0.1), (0.8, 0.8), (0.8, 0.1), (0.4, 0.2)],
                          [Path.MOVETO, Path.LINETO, Path.CURVE3, Path.CURVE3]),
                     fill=None)
ax.add_patch(p)
plt.show()

# %%
# Plotting Quadratic Curve
fig,ax = plt.subplots()
p = patches.PathPatch(Path([(0.1, 0.1), (0.8, 0.8), (0.8, 0.1), (0.4, 0.2)],
                          [Path.MOVETO, Path.LINETO, Path.CURVE3, Path.MOVETO]),
                     fill=None)
ax.add_patch(p)
plt.show()

# %%
# Working with Annotations
import matplotlib
import matplotlib.pyplot as plt

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
ax.annotate('min value', xy=(1, 2), xytext=(1.5, 2.0), arrowprops=dict(color='g'))
plt.show()

# %%
# chaning the arrow position
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
ax.annotate('min value', xy=(1, 2), xytext=(1, 3), arrowprops=dict(color='g'))
plt.show()

# %%
# other arrowprops properties
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
ax.annotate('min value', xy=(1, 2), xytext=(1, 3), arrowprops=dict(facecolor='y', edgecolor="green",alpha=0.3))
plt.show()

# %%
# adding circle on line axis plot
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
ax.annotate('Significant Point', xy=(2, 4), xytext=(2.0, 2.5), arrowprops=dict(color='g'))
ax.plot([2],[4], "ro")
plt.show()

# %%
# avoiding overlapping of arrow and markers (shrink by %)
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [2, 4, 6])
ax.annotate('Significant Point', xy=(2, 4), xytext=(2.0, 2.5), arrowprops=dict(color='g', shrink=0.1))
ax.plot([2],[4], "go")
plt.show()

# %%
import numpy as np

np.random.seed(0)

x1 = -1 + np.random.randn(100)
y1 = -1 + np.random.randn(100)

x2 = 1 + np.random.randn(100)
y2 = 1 + np.random.randn(100)

# %%
fig, ax = plt.subplots()
ax.scatter(x1, y1, color='r')
ax.scatter(x2, y2, color='g')
plt.show()

# %%
# adding annotation texts
fig, ax = plt.subplots()
ax.scatter(x1, y1, color='r')
ax.scatter(x2, y2, color='g')
bbox_props = dict(boxstyle='square', facecolor='w', alpha=0.5)
ax.text(-2, -2, 'Sample A', ha='center', va='center', size=20, bbox=bbox_props)
ax.text(2, 2, 'Sample B', ha='center', va='center', size=20, bbox=bbox_props)
plt.show()

# %%
# adding arrow
fig, ax = plt.subplots()
ax.scatter(x1, y1, color='r')
ax.scatter(x2, y2, color='g')
bbox_props = dict(boxstyle='square', facecolor='w', alpha=0.5)
ax.text(-2, -2, 'Sample A', ha='center', va='center', size=20, bbox=bbox_props)
ax.text(2, 2, 'Sample B', ha='center', va='center', size=20, bbox=bbox_props)
arrow_bbox_props = dict(boxstyle='rarrow', facecolor='lightblue', edgecolor='b', linewidth=2,alpha=0.7)
ax.text(0, 0, 'Direction', ha='center', va='center', rotation=60, size=15, bbox=arrow_bbox_props)
# text rotation is specified and arrow rotate accordingly
plt.show()

# %%
# Wokring with Scales

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
np.random.seed()

# %%
y = np.random.uniform(low=0.0, high=1000, size=(1000,))
y.sort()
x = np.arange(len(y))

# %%
plt.plot(x, y)
plt.grid(True)  # enabling grid lines for our plot
plt.yscale('linear') # by default scale for plot is linear. we state it explicitly here
plt.show()

# %%
# log scale yaxis
plt.plot(x, y)
plt.grid(True)  
plt.yscale('log')
plt.show()

# %%
# changing log base
plt.plot(x, y)
plt.grid(True)  
plt.yscale('log', base=2)
plt.show()

# %%
# changing XY axis log scale separately
plt.plot(x, y)
plt.grid(True)  
plt.yscale('log', base=10)
plt.xscale('log', base=2)
plt.show()

# %% [markdown]
# **Working with scales**

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
# https://www.kaggle.com/grubenm/austin-weather/data/
austin_weather = pd.read_csv("austin_weather.csv")
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
austin_weather = austin_weather[['Date', 'TempAvgF', 'WindAvgMPH']].head(30)
austin_weather
# Out:
#           Date  TempAvgF WindAvgMPH
# 0   2013-12-21        60          4
# 1   2013-12-22        48          6
# 2   2013-12-23        45          3
# 3   2013-12-24        46          4
# 4   2013-12-25        50          2
# 5   2013-12-26        48          3
# 6   2013-12-27        53          1
# 7   2013-12-28        51          2
# 8   2013-12-29        50          5
# 9   2013-12-30        40          5
# 10  2013-12-31        46          1
# 11  2014-01-01        54          4
# 12  2014-01-02        44          8
# 13  2014-01-03        43          4
# 14  2014-01-04        57          7
# 15  2014-01-05        47         10
# 16  2014-01-06        29          7
# 17  2014-01-07        35          5
# 18  2014-01-08        47          1
# 19  2014-01-09        62          3
# 20  2014-01-10        65          6
# 21  2014-01-11        62          3
# 22  2014-01-12        57          4
# 23  2014-01-13        57          7
# 24  2014-01-14        57          5
# ...

# %%
# twin axis plot

fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='red')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='red')

# adding extra info 
ax_wind = ax_tempF.twinx()

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='red')

# adding extra info 
ax_wind = ax_tempF.twinx()
ax_wind.set_ylabel('Avg Wind Speed (MPH)', 
                   color='blue',
                   size='x-large')

ax_wind.tick_params(axis='y', 
                    labelcolor='blue', 
                    labelsize='large')

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='red')

# adding extra info 
ax_wind = ax_tempF.twinx()
ax_wind.set_ylabel('Avg Wind Speed (MPH)', 
                   color='blue',
                   size='x-large')

ax_wind.tick_params(axis='y', 
                    labelcolor='blue', 
                    labelsize='large')

ax_wind.plot(austin_weather['Date'],
             austin_weather['WindAvgMPH'],
             color='blue')

# %%
def fahrenheit2celsius(f):
    return (f - 32) * 5/9

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='green')

ax_tempC = ax_tempF.twinx()

# %%
fig, ax_tempF = plt.subplots()

fig.set_figwidth(12)
fig.set_figheight(6)

ax_tempF.set_xlabel('Date')
ax_tempF.tick_params(axis = 'x', 
                     bottom=False, 
                     labelbottom=False)

ax_tempF.set_ylabel('Temp (F)', 
                    color='red',
                    size='x-large')

ax_tempF.tick_params(axis='y', 
                     labelcolor='red',
                     labelsize='large')

ax_tempF.plot(austin_weather['Date'], 
              austin_weather['TempAvgF'],
              color='green')

ax_tempC = ax_tempF.twinx()
ymin, ymax = ax_tempF.get_ylim()

ax_tempC.set_ylim((fahrenheit2celsius(ymin),
                   fahrenheit2celsius(ymax)))

ax_tempC.set_ylabel('Temp (C)', 
                    color='blue',
                    size='x-large')

ax_tempC.tick_params(axis='y', 
                     labelcolor='blue',
                    labelsize='large')

# %% [markdown]
# ## Visualizing Statistical Data

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
x = np.random.randint(low=0, high=20, size=20)
x.sort()
x
# Out:
# array([ 0,  0,  2,  3,  3,  4,  5,  5,  6,  7,  9,  9, 11, 11, 12, 12, 13,
#        14, 18, 19])

# %%
# box plot - default represents values between 25th and 75th percentiles
# central line represent median
# The top and bottom caps represents the range of values (excluding outliers in data)
# The whiskers are the bars which connect the box with the caps

plt.boxplot(x)
plt.show()

# %%
# adding a value to see change in the dimension of boxplot

x = np.append(x, 22)
plt.boxplot(x)
plt.show()

# %%
x = np.append(x, 37)
x = np.append(x, 40)

plt.boxplot(x)
plt.show()
# Note: Outliers are representd by circles outside the box called fliers

# %%
plt.boxplot(x, vert=False)
plt.show()

# %%
# highlighting median value

plt.boxplot(x, 
            vert=False, 
            notch=True)
plt.show()

# %%
# to disable outliers

plt.boxplot(x, 
            vert=False, 
            notch=True,
            showfliers=False)
plt.show()

# %%
# making boxplot 2-D

bp = plt.boxplot(x, patch_artist=True)
bp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dc5fd38be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dc5ffd14c0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1dc5edd01f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dc5ffd1cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dc5e3c0460>],
#  'means': []}

# %%
# boxplot is basically just a dictionary

print('Number of boxes: ', len(bp['boxes']))
print('Number of whiskers: ', len(bp['whiskers']))
print('Number of caps: ',len(bp['caps']))
print('Number of medians: ',len(bp['medians']))
print('Number of fliers: ',len(bp['fliers']))
# Out:
# Number of boxes:  1
# Number of whiskers:  2
# Number of caps:  2
# Number of medians:  1
# Number of fliers:  1

# %%
# Customizing components of boxplots seperately

bp = plt.boxplot(x, patch_artist=True)
bp['boxes'][0].set(facecolor='lightyellow',
                   edgecolor='maroon',
                   hatch='.')
# Out:
# [None, None, None]

# %%
# Customizing components of boxplots seperately

bp = plt.boxplot(x, patch_artist=True)
bp['boxes'][0].set(facecolor='lightyellow',
                   edgecolor='maroon',
                   hatch='.')

bp['whiskers'][0].set(color='red',
                      linewidth=2)

bp['whiskers'][1].set(color='blue')
# Out:
# [None]

# %%
bp = plt.boxplot(x, patch_artist=True)

bp['boxes'][0].set(facecolor='lightyellow',
                   edgecolor='maroon')

bp['medians'][0].set(linestyle = '--',
                     linewidth = 3)
# Out:
# [None, None]

# %%
# Using datasets

exam_data = pd.read_csv("exams.csv")
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
exam_scores = exam_data[['math score', 'reading score', 'writing score']]
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
exam_scores.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
# converting pandas dataframe to numpy array

exam_scores_array = np.array(exam_scores)
exam_scores_array
# Out:
# array([[ 69,  61,  58],
#        [ 47,  65,  69],
#        [ 66,  52,  53],
#        [ 88,  89,  82],
#        [ 62,  82,  76],
#        [ 47,  69,  60],
#        [ 71,  66,  74],
#        [ 57,  62,  60],
#        [ 60,  67,  65],
#        [ 74,  72,  76],
#        [ 77,  71,  67],
#        [ 69,  79,  83],
#        [ 65,  62,  56],
#        [ 55,  58,  51],
#        [ 78,  88,  91],
#        [ 70,  72,  72],
#        [ 55,  69,  55],
#        [ 68,  68,  62],
#        [ 73,  62,  58],
#        [ 54,  50,  51],
#        [ 81,  76,  77],
#        [ 70,  76,  73],
#        [ 64,  62,  63],
#        [ 51,  66,  63],
#        [ 49,  50,  43],
#        [ 83,  80,  82],
#        [ 86,  92,  81],
#        [ 83,  89,  94],
#        [ 61,  77,  68],
#        [ 55,  50,  44],
#        [ 56,  59,  55],
#        [ 46,  57,  61],
#        [ 68,  60,  52],
#        [ 78,  75,  69],
#        [ 85,  94,  93],
#        [ 95,  99,  95],
#        [ 82,  74,  78],
#        [ 94,  85,  96],
# ...

# %%
bp = plt.boxplot(exam_scores_array)
plt.show()
# each subject box plot

# %%
bp = plt.boxplot(exam_scores_array,
                 patch_artist=True)

# %%
print('Number of boxes: ', len(bp['boxes']))
print('Number of whiskers: ', len(bp['whiskers']))
print('Number of caps: ',len(bp['caps']))
print('Number of medians: ',len(bp['medians']))
print('Number of fliers: ',len(bp['fliers']))
# Out:
# Number of boxes:  3
# Number of whiskers:  6
# Number of caps:  6
# Number of medians:  3
# Number of fliers:  3

# %%
colors = ['blue', 'grey', 'lawngreen']

bp = plt.boxplot(exam_scores_array,
                 patch_artist=True)

for i in range(len(bp['boxes'])):
    bp['boxes'][i].set(facecolor=colors[i])
    bp['caps'][2*i + 1].set(color=colors[i])

# %%
colors = ['blue', 'grey', 'lawngreen']

bp = plt.boxplot(exam_scores_array,
                 patch_artist=True)

for i in range(len(bp['boxes'])):
    bp['boxes'][i].set(facecolor=colors[i])
    bp['caps'][2*i + 1].set(color=colors[i])
    
# specifying corresponding box x-labels
plt.xticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
# Out:
# ([<matplotlib.axis.XTick at 0x1dc62c93760>,
# ...
#  [Text(1, 0, 'Math'), Text(2, 0, 'Reading'), Text(3, 0, 'Writing')])

# %% [markdown]
# **Violin Plots**

# %%
vp = plt.violinplot(exam_scores_array)
plt.show()
# display density of dataset over particular range of values

# %%
# showing medians in violin plots

vp = plt.violinplot(exam_scores_array,
                    showmedians=True)
plt.xticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
plt.show()

# %%
vp = plt.violinplot(exam_scores_array,
                    showmedians=True, 
                    vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
plt.show()

# %%
# return patch objects
vp
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dc62c39ca0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dc62c39b20>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dc62cd78b0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dc62cd7c40>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1dc62cd7fd0>}

# %%
# only above listed components can be customized in violin plots
vp = plt.violinplot(exam_scores_array,
                    showmedians=True, 
                    vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolor=colors[i])

# %%
vp = plt.violinplot(exam_scores_array,
                    showmedians=True, 
                    vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolor=colors[i])
    
vp['cmaxes'].set(color='maroon')
vp['cmins'].set(color='black')
vp['cbars'].set(linestyle=':')
vp['cmedians'].set(linewidth=6)
# Out:
# [None]

# %%
# setup legends

vp = plt.violinplot(exam_scores_array,
                    showmedians=True, 
                    vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolor=colors[i])
    
plt.legend(handles = [vp['bodies'][0], vp['bodies'][1]],
           labels = ['Math', 'Reading'],
           loc = 'upper left')

# %% [markdown]
# **Histograms**

# %%
np_data = pd.read_csv('national_parks.csv')
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
np_data.describe()
# Out:
#               Year      Badlands   GrandCanyon   BryceCanyon
# count    57.000000  5.700000e+01  5.700000e+01  5.700000e+01
# mean   1989.000000  1.069524e+06  3.412695e+06  8.408708e+05
# std      16.598193  1.574500e+05  1.255127e+06  4.816281e+05
# min    1961.000000  8.333000e+05  1.253000e+06  2.510000e+05
# 25%    1975.000000  9.502420e+05  2.258200e+06  4.715170e+05
# 50%    1989.000000  1.054325e+06  3.859886e+06  8.080450e+05
# 75%    2003.000000  1.188700e+06  4.401522e+06  1.081521e+06
# max    2017.000000  1.518396e+06  6.254238e+06  2.571684e+06

# %%
plt.hist(np_data['GrandCanyon'],
         facecolor='cyan',
         edgecolor='blue',
         bins=10)
plt.show()
# bins = number of bars (in simple terms)

# %%
# components of histogram

n, bins, patches = plt.hist(np_data['GrandCanyon'],
                            facecolor='cyan',
                            edgecolor='blue',
                            bins=10)
print('n: ', n)
print('bins: ', bins)
print('patches: ', patches)
# Out:
# n:  [ 5.  9. 10.  2.  1.  9. 16.  2.  1.  2.]
# bins:  [1253000.  1753123.8 2253247.6 2753371.4 3253495.2 3753619.  4253742.8
#  4753866.6 5253990.4 5754114.2 6254238. ]
# patches:  <BarContainer object of 10 artists>

# %%
# plotting probability density

n, bins, patches = plt.hist(np_data['GrandCanyon'],
                            facecolor='cyan',
                            edgecolor='blue',
                            bins=10,
                            density=True)
print('n: ', n)
print('bins: ', bins)
print('patches: ', patches)
# Out:
# n:  [1.75395169e-07 3.15711304e-07 3.50790337e-07 7.01580675e-08
#  3.50790337e-08 3.15711304e-07 5.61264540e-07 7.01580675e-08
#  3.50790337e-08 7.01580675e-08]
# bins:  [1253000.  1753123.8 2253247.6 2753371.4 3253495.2 3753619.  4253742.8
#  4753866.6 5253990.4 5754114.2 6254238. ]
# patches:  <BarContainer object of 10 artists>

# %%
# cumalative plot
n, bins, patches = plt.hist(np_data['GrandCanyon'],
                            facecolor='cyan',
                            edgecolor='blue',
                            bins=10,
                            density=True,
                            cumulative=True)
plt.show()

# %%
plt.hist(np_data['GrandCanyon'],
         facecolor='cyan',
         edgecolor='blue',
         bins=10)

# adding second histogram

plt.hist(np_data['BryceCanyon'],
         facecolor='lightyellow',
         edgecolor='maroon',
         bins=8)


plt.show()

# %%
# swithcing the position

plt.hist(np_data['BryceCanyon'],
         facecolor='lightyellow',
         edgecolor='maroon',
         bins=8)


plt.hist(np_data['GrandCanyon'],
         facecolor='cyan',
         edgecolor='blue',
         bins=10)

plt.show()

# %%
# Using opacity of graph
plt.hist(np_data['BryceCanyon'],
         facecolor='lightyellow',
         edgecolor='maroon',
         bins=8)


plt.hist(np_data['GrandCanyon'],
         facecolor='cyan',
         edgecolor='blue',
         bins=10, 
         alpha=0.3)

plt.show()

# %% [markdown]
# **Pie Charts**

# %%
data = pd.read_csv('sector_weighting.csv')
data
# Out:
#               Sector  Percentage
# 0  General Financial          20
# 1          Beverages          35
# 2     Life Insurance          25
# 3            Tobacco           5
# 4             Travel          15

# %%
plt.pie(data['Percentage'],
        labels=data['Sector'])

plt.show()

# %%
plt.pie(data['Percentage'],
        labels=data['Sector'])

plt.axis('equal')

plt.show()

# %%
colors = ['deeppink', 'aqua', 'magenta', 'silver', 'lime']
plt.pie(data['Percentage'], 
        labels=data['Sector'],
        colors = colors,
        autopct='%.2f')

plt.axis('equal')
plt.show()

# %%
# changing the angles

plt.pie(data['Percentage'], 
        labels=data['Sector'],
        colors = colors,
        autopct='%.2f',
        startangle=90,
        counterclock=False)

plt.axis('equal')
plt.show()

# %%
# exlpode allows us to highlights a wedge in the pie chart by
# seperating it from the pie by a fraction of its radius

explode = (0, 0.1, 0, 0.3, 0)
plt.pie(data['Percentage'], 
        labels=data['Sector'],
        colors = colors,
        autopct='%.2f',
        startangle=90,
        counterclock=False,
        explode=explode)

plt.axis('equal')
plt.show()

# %%
# Components of Poe chart

wedges, texts, autotexts = plt.pie(data['Percentage'], 
                                   labels=data['Sector'],
                                   colors = colors,
                                   autopct='%.2f',
                                   startangle=90,
                                   counterclock=False,
                                   explode=explode)

plt.axis('equal')
print("Wedges: ", wedges)
print("Texts: ", texts)
print("Autotexts: ", autotexts)
# Out:
# Wedges:  [<matplotlib.patches.Wedge object at 0x000001DC62F9CAC0>, <matplotlib.patches.Wedge object at 0x000001DC62F71CD0>, <matplotlib.patches.Wedge object at 0x000001DC62F71B50>, <matplotlib.patches.Wedge object at 0x000001DC62F902E0>, <matplotlib.patches.Wedge object at 0x000001DC62F8E040>]
# Texts:  [Text(0.6465637858537406, 0.8899186877588752, 'General Financial'), Text(0.8485281374238571, -0.8485281374238571, 'Beverages'), Text(-0.9801071672559597, -0.49938956806635293, 'Life Insurance'), Text(-1.2474091442776014, 0.6355866791969627, 'Tobacco'), Text(-0.4993895451252887, 0.9801071789450159, 'Travel')]
# Autotexts:  [Text(0.35267115592022213, 0.4854101933230227, '20.00'), Text(0.4949747468305833, -0.4949747468305833, '35.00'), Text(-0.5346039094123416, -0.2723943098543743, '25.00'), Text(-0.8019058784641722, 0.4085914366266188, '5.00'), Text(-0.2723942973410665, 0.5346039157881904, '15.00')]

# %%
wedges, texts, autotexts = plt.pie(data['Percentage'], 
                                   labels=data['Sector'],
                                   colors = colors,
                                   autopct='%.2f',
                                   startangle=90,
                                   counterclock=False,
                                   explode=explode)

plt.axis('equal')

wedges[1].set(edgecolor='blue', linewidth=2)
texts[1].set(family='cursive', size=20)
autotexts[1].set(weight='bold', size=15)

# %%
# for autocorelation plots refer to doc

# %% [markdown]
# **Stacked Plots**

# %%
np_data = pd.read_csv('national_parks.csv')
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x = np_data['Year']
y = np.vstack([np_data['Badlands'],
               np_data['GrandCanyon'],
               np_data['BryceCanyon']])
y
# Out:
# array([[ 833300, 1044800, 1074000, 1079800, 1091300, 1094800, 1188700,
#         1194600, 1221300, 1303100, 1282000, 1274600, 1387900, 1205300,
#         1153200, 1210100, 1305400, 1234915,  858000,  952652, 1175952,
#         1030484, 1026981, 1113675,  950242, 1025630, 1174398, 1110040,
#         1237956, 1326475, 1518396, 1205297, 1179458, 1130459, 1075569,
#         1024705,  970696, 1021049,  950453, 1105824,  955469,  908898,
#          871034,  936030,  909146,  840118,  886654,  845734,  933918,
#          977778,  870741,  883406,  892372,  868094,  989354,  996263,
#         1054325],
#        [1253000, 1447400, 1539500, 1576600, 1689200, 1806000, 1804900,
#         1986300, 2192600, 2258200, 2402100, 2698300, 1909700, 1888600,
#         2625100, 2791600, 2627200, 2748642, 2131716, 2304973, 2472270,
#         2293127, 2248082, 2173584, 2711529, 3035787, 3513030, 3859886,
#         3966209, 3776685, 3886031, 4203545, 4575602, 4364316, 4557645,
# ...

# %%
labels = ['Badlands','GrandCanyon','BryceCanyon']
plt.stackplot(x, y, 
              labels=labels)

plt.legend(loc='upper left')
plt.show()

# %%
colors = ['sandybrown', 'tomato', 'skyblue']

plt.stackplot(x, y, 
              labels=labels,
              colors=colors,
              edgecolor='grey')

plt.legend(loc='upper left')
plt.show()

# %%
np_data[['Badlands', 'GrandCanyon', 'BryceCanyon']].diff()
# Out:
#     Badlands  GrandCanyon  BryceCanyon
# 0        NaN          NaN          NaN
# 1   211500.0     194400.0     -13800.0
# 2    29200.0      92100.0      38500.0
# 3     5800.0      37100.0      10800.0
# 4    11500.0     112600.0      66500.0
# 5     3500.0     116800.0      29800.0
# 6    93900.0      -1100.0    -101600.0
# 7     5900.0     181400.0      25800.0
# 8    26700.0     206300.0      46100.0
# 9    81800.0      65600.0     -21000.0
# 10  -21100.0     143900.0      31900.0
# 11   -7400.0     296200.0      47030.0
# 12  113300.0    -788600.0       4870.0
# 13 -182600.0     -21100.0     -20900.0
# 14  -52100.0     736500.0     170400.0
# 15   56900.0     166500.0      46400.0
# 16   95300.0    -164400.0     -14100.0
# 17  -70485.0     121442.0      67760.0
# 18 -376915.0    -616926.0    -121165.0
# 19   94652.0     173257.0      13446.0
# 20  223300.0     167297.0     -97449.0
# 21 -145468.0    -179143.0      -2575.0
# 22   -3503.0     -45045.0       1116.0
# ...

# %%
# modifying data

np_data[['Badlands', 'GrandCanyon', 'BryceCanyon']] = np_data[['Badlands', 'GrandCanyon', 'BryceCanyon']].diff()
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961       NaN          NaN          NaN
# 1  1962  211500.0     194400.0     -13800.0
# 2  1963   29200.0      92100.0      38500.0
# 3  1964    5800.0      37100.0      10800.0
# 4  1965   11500.0     112600.0      66500.0

# %% [markdown]
# **Stem Plot**

# %%
plt.figure(figsize=(10, 6))

plt.stem(np_data['Year'],
        np_data['Badlands'])

plt.title('Change in Number of Visitors')
plt.show()
